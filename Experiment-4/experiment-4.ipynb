# %%
import numpy as np 
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("../Data/Dog.jpg", cv2.IMREAD_GRAYSCALE)

# %%
mean = 0
sigma = 75

# %%
noise = np.random.normal(mean, sigma, image.shape)
noisy = image.astype(np.float32) + noise
noisy = np.clip(noisy, 0, 255).astype(np.uint8)
noisy = cv2.cvtColor(noisy, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(noisy, cmap="gray")
plt.axis("off")
plt.show()

# %%
cv2_filtered = cv2.GaussianBlur( noisy, (7, 7), 2)

plt.figure(figsize=(6, 6))
plt.imshow(cv2_filtered, cmap="gray")
plt.title("Gaussian Blur using OpenCV")
plt.axis("off")
plt.show()

# %%
def gaussian_filter(image, kernel_size=7, sigma=2):
    k = kernel_size // 2

    # Create Gaussian kernel
    x, y = np.mgrid[-k:k+1, -k:k+1]
    kernel = (1 / (2 * np.pi * sigma**2)) * np.exp(-(x**2 + y**2) / (2 * sigma**2))
    kernel /= np.sum(kernel)

    # Padding
    padded = np.pad( image, ((k, k), (k, k)), mode='edge')

    out_h, out_w = image.shape
    filtered = np.zeros((out_h, out_w), dtype=np.float32)

    # Convolution
    for i in range(out_h):
        for j in range(out_w):
            region = padded[i:i + kernel_size, j:j + kernel_size]
            filtered[i, j] = np.sum(region * kernel)

    return np.clip(filtered, 0, 255).astype(np.uint8)

# %%
my_filtered = gaussian_filter(
    noisy,
    kernel_size=7,
    sigma=2
)

plt.figure(figsize=(6, 6))
plt.imshow(my_filtered)
plt.title("Gaussian Filter - Our Implementation")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 my_filtered = gaussian_filter(
#       2     noisy,
#       3     kernel_size=7,
#       4     sigma=2
#       5 )
#       7 plt.figure(figsize=(6, 6))
#       8 plt.imshow(my_filtered)
#
# Cell In[107], line 10, in gaussian_filter(image, kernel_size, sigma)
#       7 kernel /= np.sum(kernel)
#       9 # Padding
# ---> 10 padded = np.pad( image, ((k, k), (k, k)), mode='edge')
#      12 out_h, out_w = image.shape
#      13 filtered = np.zeros((out_h, out_w), dtype=np.float32)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/_arraypad_impl.py:792, in pad(array, pad_width, mode, **kwargs)
#     789     raise TypeError('`pad_width` must be of integral type.')
#     791 # Broadcast to shape (array.ndim, 2)
# --> 792 pad_width = _as_pairs(pad_width, array.ndim, as_index=True)
#     794 if callable(mode):
#     795     # Old behavior: Use user-supplied function with np.apply_along_axis
#     796     function = mode
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/_arraypad_impl.py:535, in _as_pairs(x, ndim, as_index)
#     531     raise ValueError("index can't contain negative values")
#     533 # Converting the array with `tolist` seems to improve performance
#     534 # when iterating and indexing the result (see usage in `pad`)
# --> 535 return np.broadcast_to(x, (ndim, 2)).tolist()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/_stride_tricks_impl.py:443, in broadcast_to(array, shape, subok)
#     400 @array_function_dispatch(_broadcast_to_dispatcher, module='numpy')
#     401 def broadcast_to(array, shape, subok=False):
#     402     """Broadcast an array to a new shape.
#     403
#     404     Parameters
#    (...)
#     441            [1, 2, 3]])
#     442     """
# --> 443     return _broadcast_to(array, shape, subok=subok, readonly=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/_stride_tricks_impl.py:382, in _broadcast_to(array, shape, subok, readonly)
#     379     raise ValueError('all elements of broadcast shape must be non-'
#     380                      'negative')
#     381 extras = []
# --> 382 it = np.nditer(
#     383     (array,), flags=['multi_index', 'refs_ok', 'zerosize_ok'] + extras,
#     384     op_flags=['readonly'], itershape=shape, order='C')
#     385 with it:
#     386     # never really has writebackifcopy semantics
#     387     broadcast = it.itviews[0]
#
# ValueError: operands could not be broadcast together with remapped shapes [original->remapped]: (2,2)  and requested shape (3,2)

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(cv2_filtered)
plt.title("OpenCV Gaussian Blur")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(my_filtered)
plt.title("Our Gaussian Filter")
plt.axis("off")

plt.tight_layout()
plt.show()
